# %% [markdown]
# # analyze wave signals

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pylab as plt
import datetime as dt
import glob
import os
import xarray as xr
import numpy as np

from mpl_toolkits.basemap import Basemap

# %%
# keepdat=["device_id","UTC_datetime","UTC_date","UTC_time","datatype","satcount","Latitude","Longitude","depth_m",
#          "conductivity_mS/cm","ext_temperature_C"]

# keepdat=["device_id","UTC_datetime","UTC_date","UTC_time","datatype","satcount","Latitude","Longitude","depth_m",
#          "conductivity_mS/cm","ext_temperature_C"]

keepdat=["device_id","UTC_datetime","UTC_date","UTC_time","datatype","satcount","Latitude","Longitude","depth_m","acc_x","acc_y","acc_z","milliseconds","UTC_timestamp"
         ]

# %%
##### show all the columns of the Pandas DataFrame
# pd.set_option('display.max_columns',None)

def pd_read_pattern(pattern):
    files = glob.glob(pattern)
 
    dfs = pd.DataFrame()
#     print(dfs)
    for f in files:
        
        print (f)
        
        dfs = dfs.append(pd.read_csv(f,parse_dates=True,index_col='UTC_datetime',
                          usecols=keepdat))
        
        # dfs.drop(dfs[dfs['datatype'] == 'SEN_ACC_5Hz'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'SEN_ACC_5Hz_END'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'SEN_ACC_5Hz_START'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'SEN_ACC_5Hz_ENDINT'].index, inplace = True)
        dfs.drop(dfs[dfs['datatype'] == 'SEND_ALL2_1Hz'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'SEND_ALL2_1Hz_START'].index, inplace = True)
        dfs.drop(dfs[dfs['datatype'] == 'SEND_ALL2_1Hz_END'].index, inplace = True)
        
# keep the GPS lines to get lon/lat for the location of birds
        # dfs.drop(dfs[dfs['datatype'] == 'GPS'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'GPSS'].index, inplace = True)
        # dfs.drop(dfs[dfs['datatype'] == 'GPSD'].index, inplace = True))
        # dfs.drop(dfs[dfs['datatype'] == 'GPSF'].index, inplace = True)

    return dfs #.reset_index(drop=True)

# %%
# get IDs observed in UAEBUS///
# idfs = pd.DataFrame()
idfile = '/home/server/pi/homes/liux8/work/mnt/Field_Data/Deployment_Field_Data.csv';
IDS = pd.read_csv(idfile,encoding='latin-1')
IDS.drop(IDS[IDS['Project_ID'] != 'USACRBRPE19'].index, inplace = True)
IDS.columns
# kuae = IDS(strcmp(IDS.Var4,'UAEBUSO20'),:);
# idnumber0 = [];
# for i = 1:size(kuae.Var14,1)
#    idnumber0 = kuae.Var14{i};
#    idnum{i} = idnumber0(:,end-5:end);
# end
# id_total = size(idnum,1);
# IDS['Deployment_ID'].shape[0]
# Out:
# Index(['ProjectTitle', 'PIEmail', 'DataManagerEmail', 'Project_ID', 'Bird_ID',
#        'Species_Code', 'Species', 'Capture_Site', 'Capture_Country',
#        'Capture_Number', 'Capture_Date', 'Capture_Time', 'Release_Date',
#        'Release_Time', 'Deployment_ID', 'DeploymentStartDatetime',
#        'UTC_offset_deploy', 'DeploymentLatitude', 'DeploymentLongitude',
#        'TagManufacture', 'TagModel', 'Sensors', 'TagSerialNumber', 'USGS_Band',
#        'Aux_Band_Code', 'Aux_Band_Color', 'Tarsus_mm', 'Culmen_mm',
#        'Wing_Chord_cm', 'Total_Weight_kg', 'Bag_Weight_kg', 'Bird_Weight_kg',
#        'Sex_Mass', 'Feathers_YN', 'AnimalAgeClass', 'Plumage_Notes', 'Notes',
#        'DeploymentEndDatetime_UTC', 'Deployment_End_Notes',
#        'Deployment_End_Short', 'DeploymentEndConfirmedYN',
#        'DataEmbargoUntilDate', 'Status', 'Tagging_person', 'Breeding_Status',
#        'Nest_Contents', 'Recapture_Y/N', 'Recapture_Date', 'Recapture_Time',
#        'ReRelease_Date', 'ReRelease_Time', 'Recapture_Bird_Weight_kg',
#        'Recapture_Notes'],
#       dtype='object')

# %%
IDS['number'] = pd.to_numeric(IDS['Deployment_ID'].str.extract(r'^(\d+)_', expand=False), errors='coerce')
IDS = IDS[IDS['number'] > 4]
dfs = pd.DataFrame()
for iid in range(IDS['Deployment_ID'].shape[0]):
# for iid in range(7,8):
    id = IDS['Deployment_ID'].values[iid][-6:]

    print(id)
    # dfs = dfs.append(pd_read_pattern('/home/server/pi/homes/liux8/work/mnt/bird_ATN_files/'+IDS['Project_ID'].values[iid]+'/gps_sensors_v2/'+id+'_20??_[0-1][0-9].csv'))
    dfs = dfs.append(pd_read_pattern('/home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/'+id+'_20??_[0-1][0-9].csv'))
    if not dfs.empty:
        # dfs=dfs.loc['2021-01-01':'2021-12-31']

        dfs['date']=pd.to_datetime(dfs['UTC_date']+' '+dfs['UTC_time'], format='%Y-%m-%d %H:%M:%S')

        threshold = pd.Timedelta(minutes=3)
    print(dfs['device_id'][0:5])
# Out:
# 192000
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192000_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192000_2019_07.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191992
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191992_2020_02.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191995
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191995_2020_02.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191998
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191998_2020_02.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191999
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191999_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191999_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191999_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191999_2019_09.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191990
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191990_2020_01.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191996
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_03.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2020_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_03.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2021_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_03.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191996_2022_11.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191991
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_03.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2020_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_03.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191991_2021_06.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191997
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191997_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191997_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191997_2019_08.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191993
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191993_2019_12.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 191989
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191989_2019_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191989_2019_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191989_2019_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/191989_2019_09.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 733569
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 737313
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 744392
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 192762
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192762_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192762_2019_10.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 192761
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192761_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192761_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192761_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192761_2019_12.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 192760
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192760_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192760_2019_10.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 192759
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2020_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2020_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2021_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2022_05.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2022_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2022_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2022_12.csv
# /tmp/ipykernel_160284/1623357449.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = dfs.append(pd.read_csv(f,parse_dates=True,index_col='UTC_datetime',
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2023_03.csv
# /tmp/ipykernel_160284/1623357449.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = dfs.append(pd.read_csv(f,parse_dates=True,index_col='UTC_datetime',
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2023_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192759_2024_01.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64
# 192758
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2019_09.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2019_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2019_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2019_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2020_01.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2020_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2020_06.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2020_07.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2020_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_04.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_08.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_09.csv
# /tmp/ipykernel_160284/1623357449.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = dfs.append(pd.read_csv(f,parse_dates=True,index_col='UTC_datetime',
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_10.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_11.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2022_12.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2023_01.csv
# /tmp/ipykernel_160284/1623357449.py:13: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs = dfs.append(pd.read_csv(f,parse_dates=True,index_col='UTC_datetime',
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2023_02.csv
# /home/server/pi/homes/liux8/work/mnt/2019_BRAC_Ornitela/raw_csv_monthly/192758_2023_05.csv
# UTC_datetime
# 2019-06-04 17:52:55    192000
# 2019-06-04 17:53:16    192000
# 2019-06-04 17:54:17    192000
# 2019-06-04 17:55:17    192000
# 2019-06-04 17:56:17    192000
# Name: device_id, dtype: int64

# %%
dfs[(dfs['date']>=pd.to_datetime('2020-5-15 3:36'))&(dfs['date']<=pd.to_datetime('2020-5-15 9:42'))&(dfs['device_id']==191991)]
# Out:
#                      device_id    UTC_date  UTC_time            datatype  \
# UTC_datetime
# 2020-05-15 03:36:03     191991  2020-05-15  03:36:03  SEND_ALL_5Hz_START
# 2020-05-15 03:36:03     191991  2020-05-15  03:36:03        SEND_ALL_5Hz
# 2020-05-15 03:36:03     191991  2020-05-15  03:36:03        SEND_ALL_5Hz
# 2020-05-15 03:36:03     191991  2020-05-15  03:36:03        SEND_ALL_5Hz
# 2020-05-15 03:36:03     191991  2020-05-15  03:36:03        SEND_ALL_5Hz
# ...                        ...         ...       ...                 ...
# 2020-05-15 03:36:44     191991  2020-05-15  03:36:44        SEND_ALL_5Hz
# 2020-05-15 03:36:44     191991  2020-05-15  03:36:44    SEND_ALL_5Hz_END
# 2020-05-15 03:40:25     191991  2020-05-15  03:40:25                 GPS
# 2020-05-15 06:41:01     191991  2020-05-15  06:41:01                 GPS
# 2020-05-15 09:41:06     191991  2020-05-15  09:41:06                 GPS
#
#                     satcount   Latitude   Longitude  acc_x   acc_y  acc_z  \
# UTC_datetime
# 2020-05-15 03:36:03      NaN        NaN         NaN  325.0   516.0  686.0
# 2020-05-15 03:36:03      NaN        NaN         NaN  239.0   883.0  255.0
# 2020-05-15 03:36:03      NaN        NaN         NaN   48.0  1089.0  146.0
# 2020-05-15 03:36:03      NaN        NaN         NaN   85.0  1081.0  235.0
# 2020-05-15 03:36:03      NaN        NaN         NaN  436.0   662.0  530.0
# ...                      ...        ...         ...    ...     ...    ...
# 2020-05-15 03:36:44      NaN        NaN         NaN   31.0  -673.0  543.0
# 2020-05-15 03:36:44      NaN        NaN         NaN  -65.0  -397.0  559.0
# 2020-05-15 03:40:25      7.0  46.256283 -123.982071  102.0  -753.0  662.0
# 2020-05-15 06:41:01     12.0  46.256168 -123.982147  191.0  -805.0  584.0
# 2020-05-15 09:41:06      6.0  46.256203 -123.982193 -205.0  -727.0  654.0
#
#                                                    UTC_timestamp  \
# UTC_datetime
# 2020-05-15 03:36:03  2020-05-15 03:36:03.2020-05-15 03:36:03.020
# 2020-05-15 06:41:01  46.256168 -123.982147  191.0 -805.0  584.0           0.0
# 2020-05-15 09:41:06  46.256203 -123.982193 -205.0 -727.0  654.0           0.0
#
#                      depth_m                date Latitude_1 Longitude_1
# UTC_datetime
# 2020-05-15 03:36:15      NaN 2020-05-15 03:36:15  49.002048 -123.112259
# 2020-05-15 03:36:44      NaN 2020-05-15 03:36:44  49.002052 -123.112251
# 2020-05-15 03:37:15      NaN 2020-05-15 03:37:15  49.002052 -123.112297
# 2020-05-15 03:37:45      NaN 2020-05-15 03:37:45   49.00206 -123.112274
# 2020-05-15 03:38:14      NaN 2020-05-15 03:38:14  49.002113 -123.112274
# 2020-05-15 03:38:44      NaN 2020-05-15 03:38:44  49.002094 -123.112282
# 2020-05-15 03:39:22      NaN 2020-05-15 03:39:22  49.002033 -123.112267
# 2020-05-15 03:39:45      NaN 2020-05-15 03:39:45   49.00201 -123.112221
# 2020-05-15 03:40:16      NaN 2020-05-15 03:40:16  49.002018 -123.112251
# 2020-05-15 03:40:46      NaN 2020-05-15 03:40:46  49.002182 -123.112312
# 2020-05-15 03:41:23      NaN 2020-05-15 03:41:23  49.002163 -123.112312
# 2020-05-15 03:41:45      NaN 2020-05-15 03:41:45  49.002106 -123.112289
# 2020-05-15 03:42:16      NaN 2020-05-15 03:42:16  49.002045 -123.112267
# 2020-05-15 03:42:45      NaN 2020-05-15 03:42:45  49.001976 -123.112282
# 2020-05-15 03:43:14      NaN 2020-05-15 03:43:14  49.002071 -123.112274
# 2020-05-15 03:43:45      NaN 2020-05-15 03:43:45  49.002075 -123.112267
# 2020-05-15 03:44:15      NaN 2020-05-15 03:44:15  49.002293 -123.112213
# 2020-05-15 03:46:45      NaN 2020-05-15 03:46:45  49.002167 -123.112328
# 2020-05-15 06:47:07      NaN 2020-05-15 06:47:07  49.002083 -123.112267
# 2020-05-15 03:40:25      NaN 2020-05-15 03:40:25        NaN         NaN
# 2020-05-15 06:41:01      NaN 2020-05-15 06:41:01  46.256283 -123.982071
# 2020-05-15 09:41:06      NaN 2020-05-15 09:41:06  46.256168 -123.982147

# %%
# dfs.drop(dfs[dfs['datatype'] == 'GPS'].index, inplace = True)

# %%
# dfs.drop(dfs[dfs['datatype'] == 'GPS'].index, inplace = True)
# dfs.drop(dfs[dfs['datatype'] == 'GPSS'].index, inplace = True)
# dfs.drop(dfs[dfs['datatype'] == 'GPSD'].index, inplace = True)
# dfs.drop(dfs[dfs['datatype'] == 'GPSF'].index, inplace = True)

# %%
# dfs=dfs[dfs['datatype'] != 'GPS']
# dfs=dfs[dfs['datatype'] != 'GPSS']
# dfs=dfs[dfs['datatype'] != 'GPSD']
# dfs=dfs[dfs['datatype'] != 'GPSF']

# %%
dfs.to_csv('~/work/GETM/scripts_ms2/waves_analysis/wave_acc/CR_acc_raw_v4_longrec_keepGPS.csv')
